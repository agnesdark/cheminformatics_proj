# %% [markdown]
# # SMILES handling

# %% [markdown]
# #### Import all the necessary libraries

# %%
import logging
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd
from rdkit import Chem
from rdkit.Chem.MolStandardize import rdMolStandardize
import seaborn as sns

# %% [markdown]
# Set the working directory to the specified path

# %%
path='' #paste your path here
os.chdir(path)
print('Path changed')
# Out:
# Path changed

# %% [markdown]
# #### Load the dataset generated by the previous notebook into a pandas DataFrame

# %%
df = pd.read_csv(os.path.join(path, 'chembl_activity_IC50_cleaned.csv'))

# %%
df.head()
# Out:
#    Unnamed: 0 action_type  activity_comment  activity_id activity_properties  \
# 0         262         NaN               NaN     20696387                  []
# 1         263         NaN               NaN     20696388                  []
# 2         264         NaN               NaN     20696389                  []
# 3         265         NaN               NaN     20696390                  []
# 4         266         NaN               NaN     20696391                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4627009  Antagonist activity at human 5HT2A receptor ex...
# 1   CHEMBL4627009  Antagonist activity at human 5HT2A receptor ex...
# 2   CHEMBL4627009  Antagonist activity at human 5HT2A receptor ex...
# 3   CHEMBL4627009  Antagonist activity at human 5HT2A receptor ex...
# 4   CHEMBL4627009  Antagonist activity at human 5HT2A receptor ex...
#
#   assay_type  assay_variant_accession  assay_variant_mutation  ...  \
# 0          F                      NaN                     NaN  ...
# 1          F                      NaN                     NaN  ...
# 2          F                      NaN                     NaN  ...
# 3          F                      NaN                     NaN  ...
# 4          F                      NaN                     NaN  ...
#
#   target_organism                target_pref_name target_tax_id text_value  \
# 0    Homo sapiens  Serotonin 2a (5-HT2a) receptor          9606        NaN
# 1    Homo sapiens  Serotonin 2a (5-HT2a) receptor          9606        NaN
# 2    Homo sapiens  Serotonin 2a (5-HT2a) receptor          9606        NaN
# 3    Homo sapiens  Serotonin 2a (5-HT2a) receptor          9606        NaN
# 4    Homo sapiens  Serotonin 2a (5-HT2a) receptor          9606        NaN
#
#    toid  type units    uo_units  upper_value    value
# 0   NaN  IC50    nM  UO_0000065          NaN    11.00
# 1   NaN  IC50    nM  UO_0000065          NaN     0.81
# 2   NaN  IC50    nM  UO_0000065          NaN     9.30
# 3   NaN  IC50    nM  UO_0000065          NaN  1300.00
# 4   NaN  IC50    nM  UO_0000065          NaN  4100.00
#
# [5 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'action_type', 'activity_comment', 'activity_id',
#        'activity_properties', 'assay_chembl_id', 'assay_description',
#        'assay_type', 'assay_variant_accession', 'assay_variant_mutation',
#        'bao_endpoint', 'bao_format', 'bao_label', 'canonical_smiles',
#        'data_validity_comment', 'data_validity_description',
#        'document_chembl_id', 'document_journal', 'document_year',
#        'ligand_efficiency', 'molecule_chembl_id', 'molecule_pref_name',
#        'parent_molecule_chembl_id', 'pchembl_value', 'potential_duplicate',
#        'qudt_units', 'record_id', 'relation', 'src_id', 'standard_flag',
#        'standard_relation', 'standard_text_value', 'standard_type',
#        'standard_units', 'standard_upper_value', 'standard_value',
#        'target_chembl_id', 'target_organism', 'target_pref_name',
#        'target_tax_id', 'text_value', 'toid', 'type', 'units', 'uo_units',
#        'upper_value', 'value'],
#       dtype='object')

# %% [markdown]
# Narrow down the number of features displayed in the DataFrame and create a separate one containing only essential information for further manipulations

# %%
df_clean = df[['assay_chembl_id','canonical_smiles','molecule_chembl_id','parent_molecule_chembl_id', 'standard_value', 'uo_units']]
df_clean.to_csv(os.path.join(path,'5HT2A_ligands_clean.csv'))
# To ease the inspection, display entire table
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_colwidth', None)  
df_clean.head(100)
# Out:
#    assay_chembl_id  \
# 0    CHEMBL4627009
# 1    CHEMBL4627009
# 2    CHEMBL4627009
# 3    CHEMBL4627009
# 4    CHEMBL4627009
# 5    CHEMBL4627009
# 6    CHEMBL4627009
# 7    CHEMBL4627009
# 8    CHEMBL4627009
# 9    CHEMBL4627009
# 10   CHEMBL4627009
# 11   CHEMBL4627009
# 12   CHEMBL4627009
# 13   CHEMBL4627009
# 14   CHEMBL4627009
# 15   CHEMBL4627009
# 16   CHEMBL4627009
# 17   CHEMBL4627009
# 18   CHEMBL4627009
# 19   CHEMBL4627009
# 20   CHEMBL4627009
# 21   CHEMBL4627009
# 22   CHEMBL4627009
# 23   CHEMBL4627009
# 24   CHEMBL4627009
# 25   CHEMBL4627009
# 26   CHEMBL4627009
# 27   CHEMBL4627009
# 28   CHEMBL4627009
# 29   CHEMBL4627009
# 30   CHEMBL4627009
# 31   CHEMBL4627009
# 32   CHEMBL4627009
# 33   CHEMBL4627009
# 34   CHEMBL5135453
# 35   CHEMBL5135453
# 36   CHEMBL5135453
# 37   CHEMBL5135453
# 38   CHEMBL5135453
# 39   CHEMBL5135453
# 40   CHEMBL5135453
# 41   CHEMBL5135453
# 42   CHEMBL5135453
# 43   CHEMBL5135453
# 44   CHEMBL5135453
# 45   CHEMBL5135453
# 46   CHEMBL5135453
# 47   CHEMBL5135453
# 48   CHEMBL5135453
# 49   CHEMBL5135453
# 50   CHEMBL5135453
# 51   CHEMBL5135453
# 52   CHEMBL5135453
# 53   CHEMBL5135453
# 54   CHEMBL5135453
# 55   CHEMBL5135453
# 56   CHEMBL5135453
# 57   CHEMBL5135453
# 58   CHEMBL5135453
# 59   CHEMBL5135453
# 60   CHEMBL5135453
# 61   CHEMBL5135453
# 62   CHEMBL5135453
# 63   CHEMBL5135453
# 64   CHEMBL5135453
# 65   CHEMBL5135453
# 66   CHEMBL5135453
# 67   CHEMBL5135453
# 68   CHEMBL5135453
# 69   CHEMBL5135453
# 70   CHEMBL5135453
# 71   CHEMBL5135453
#
#                                                                                                             canonical_smiles  \
# 0                                                                                  COc1c(O)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 1                                                                                 COc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 2                                                                              COCCOc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 3                                                                                COc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 4                                                                              COc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 5                                                                              COc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 6                                                                             COCCOc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 7                                                                           COCCOc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 8                                                                           COCCOc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 9                                                                               Oc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 10                             COc1c(OCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 11                          COc1c(OCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 12                       COc1c(OCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 13                    COc1c(OCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 14              COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 15        COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 16  COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 17                                                                                 COc1c(O)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 18                                                                                COc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 19                                                                             COCCOc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 20                                                                               COc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 21                                                                             COc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 22                                                                             COc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 23                                                                            COCCOc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 24                                                                          COCCOc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 25                                                                          COCCOc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 26                                                                              Oc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 27                             COc1c(OCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 28                          COc1c(OCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 29                       COc1c(OCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 30                    COc1c(OCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 31              COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 32        COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 33  COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 34                                                                        CC(C)COc1ccc(CNC(=O)N(Cc2ccc(F)cc2)C2CCN(C)CC2)cc1
# 35                                                                  CC(C)COc1ccc(CNC(=O)N(Cc2ccc(F)cc2)C2CCN(CCN(C)C)CC2)cc1
# 36                                                              CC(C)COc1ccc(CNC(=O)N(Cc2ccc(F)cc2)C2CCN(CC(=O)N(C)C)CC2)cc1
# 37                                                                      CC(C)COc1ccc(CNC(=O)N(Cc2ccc(F)cc2)C2CC(N(C)C)C2)cc1
#    molecule_chembl_id parent_molecule_chembl_id  standard_value    uo_units
# 0        CHEMBL489624              CHEMBL489624         11.0000  UO_0000065
# 1       CHEMBL4638006             CHEMBL4638006          0.8100  UO_0000065
# 2       CHEMBL4636980             CHEMBL4636980          9.3000  UO_0000065
# 3       CHEMBL2206440             CHEMBL2206440       1300.0000  UO_0000065
# 4       CHEMBL4646835             CHEMBL4646835       4100.0000  UO_0000065
# 5       CHEMBL4632373             CHEMBL4632373      50000.0000  UO_0000065
# 6       CHEMBL4643961             CHEMBL4643961       3900.0000  UO_0000065
# 7       CHEMBL4635729             CHEMBL4635729       6000.0000  UO_0000065
# 8       CHEMBL4645305             CHEMBL4645305      50000.0000  UO_0000065
# 9       CHEMBL4646555             CHEMBL4646555        720.0000  UO_0000065
# 10      CHEMBL4642761             CHEMBL4642761       1200.0000  UO_0000065
# 11      CHEMBL4639821             CHEMBL4639821        280.0000  UO_0000065
# 12      CHEMBL4635373             CHEMBL4635373        450.0000  UO_0000065
# 13      CHEMBL4638687             CHEMBL4638687        270.0000  UO_0000065
# 14      CHEMBL4645193             CHEMBL4645193        410.0000  UO_0000065
# 15      CHEMBL4641860             CHEMBL4641860        300.0000  UO_0000065
# 16      CHEMBL4635960             CHEMBL4635960        520.0000  UO_0000065
# 17       CHEMBL489624              CHEMBL489624         10.9600  UO_0000065
# 18      CHEMBL4638006             CHEMBL4638006          0.8128  UO_0000065
# 19      CHEMBL4636980             CHEMBL4636980          9.3330  UO_0000065
# 20      CHEMBL2206440             CHEMBL2206440       1288.2500  UO_0000065
# 21      CHEMBL4646835             CHEMBL4646835       4168.6900  UO_0000065
# 22      CHEMBL4632373             CHEMBL4632373      50118.7200  UO_0000065
# 23      CHEMBL4643961             CHEMBL4643961       3981.0700  UO_0000065
# 24      CHEMBL4635729             CHEMBL4635729       6025.6000  UO_0000065
# 25      CHEMBL4645305             CHEMBL4645305      50118.7200  UO_0000065
# 26      CHEMBL4646555             CHEMBL4646555        724.4400  UO_0000065
# 27      CHEMBL4642761             CHEMBL4642761       1202.2600  UO_0000065
# 28      CHEMBL4639821             CHEMBL4639821        288.4000  UO_0000065
# 29      CHEMBL4635373             CHEMBL4635373        446.6800  UO_0000065
# 30      CHEMBL4638687             CHEMBL4638687        275.4200  UO_0000065
# 31      CHEMBL4645193             CHEMBL4645193        407.3800  UO_0000065
# 32      CHEMBL4641860             CHEMBL4641860        302.0000  UO_0000065
# 33      CHEMBL4635960             CHEMBL4635960        512.8600  UO_0000065
# 34      CHEMBL2111101             CHEMBL2111101         27.3000  UO_0000065
# 35      CHEMBL5181824             CHEMBL5181824         75.4000  UO_0000065
# 36      CHEMBL5198862             CHEMBL5198862        252.0000  UO_0000065
# 37      CHEMBL5188595             CHEMBL5188595        138.8000  UO_0000065
# 38      CHEMBL5194786             CHEMBL5194786        110.2000  UO_0000065
# 39      CHEMBL5184703             CHEMBL5184703          8.6400  UO_0000065
# 40      CHEMBL5199061             CHEMBL5199061         14.7000  UO_0000065
# 41      CHEMBL5200635             CHEMBL5200635         43.2000  UO_0000065
# 42      CHEMBL5178732             CHEMBL5178732          2.1100  UO_0000065
# 43      CHEMBL5172822             CHEMBL5172822          2.1700  UO_0000065
# 44      CHEMBL5205903             CHEMBL5205903          0.5400  UO_0000065
# 45      CHEMBL5173703             CHEMBL5173703          1.9300  UO_0000065
# 46      CHEMBL5198919             CHEMBL5198919          4.6400  UO_0000065
# 47      CHEMBL5184906             CHEMBL5184906          4.7000  UO_0000065
# 48      CHEMBL5198741             CHEMBL5198741          2.3500  UO_0000065
# 49      CHEMBL5175451             CHEMBL5175451          4.2900  UO_0000065
# 50      CHEMBL5189473             CHEMBL5189473          3.7800  UO_0000065
# 51      CHEMBL5184297             CHEMBL5184297          3.1300  UO_0000065
# 52      CHEMBL5173149             CHEMBL5173149         33.4000  UO_0000065
# 53      CHEMBL5200074             CHEMBL5200074          2.0500  UO_0000065
# 54      CHEMBL5181432             CHEMBL5181432         18.3000  UO_0000065
# 55      CHEMBL5181200             CHEMBL5181200         67.2000  UO_0000065
# 56      CHEMBL5208211             CHEMBL5208211         26.4000  UO_0000065
# 57      CHEMBL5197899             CHEMBL5197899          3.4900  UO_0000065
# 58      CHEMBL5191581             CHEMBL5191581          9.9800  UO_0000065
# 59      CHEMBL5205849             CHEMBL5205849         20.9000  UO_0000065
# 60      CHEMBL5194545             CHEMBL5194545         21.2500  UO_0000065
# 61      CHEMBL5200155             CHEMBL5200155         17.2700  UO_0000065
# 62      CHEMBL5185362             CHEMBL5185362          6.8600  UO_0000065
# 63      CHEMBL5188950             CHEMBL5188950        125.0000  UO_0000065
# 64      CHEMBL5200788             CHEMBL5200788         12.0000  UO_0000065
# 65      CHEMBL5192882             CHEMBL5192882         27.3000  UO_0000065
# 66      CHEMBL5193532             CHEMBL5193532        500.0000  UO_0000065
# 67      CHEMBL5174421             CHEMBL5174421        500.0000  UO_0000065
# 68      CHEMBL5201875             CHEMBL5201875        500.0000  UO_0000065
# 69      CHEMBL5169670             CHEMBL5169670        500.0000  UO_0000065
# 70      CHEMBL5176379             CHEMBL5176379        500.0000  UO_0000065
# 71      CHEMBL5179185             CHEMBL5179185        500.0000  UO_0000065

# %%
#Another way to check if df contains missing values
df_clean.isna().sum()
# Out:
# assay_chembl_id              0
# canonical_smiles             0
# molecule_chembl_id           0
# parent_molecule_chembl_id    0
# standard_value               0
# uo_units                     0
# dtype: int64

# %% [markdown]
# This dataset contains no missing values. The bioactivity of these compounds is expressed as IC50 values. A new list will be created called 'bioactivity_label' to store the activity classification of each compound based on the following criteria:
#
# Labeling criteria:
# <br>molecule_ic50_value >= 10000 --> "inactive"
# <br>molecule_ic50_value <= 1000 --> "active"
# <br>molecule_ic50_value <=10000 and molecule_ic50_value >= 1000 --> "medium"

# %%
def activity_encoder(data):
    
    bioactivity_label = []
    input_data = data.copy()
    for activity_value in input_data['standard_value']:
        if float(activity_value) >= 10000:
            bioactivity_label.append("inactive")
        elif float(activity_value) <=1000:
            bioactivity_label.append("active")
        else:
            bioactivity_label.append("medium")
            
    input_data['bioactivity_label'] = bioactivity_label
    return input_data

# %%
df_encoded = activity_encoder(data=df_clean)

# %%
df_encoded.drop(['assay_chembl_id', 'molecule_chembl_id','parent_molecule_chembl_id','uo_units'],axis=1)
# Out:
#                                                                                                             canonical_smiles  \
# 0                                                                                  COc1c(O)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 1                                                                                 COc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 2                                                                              COCCOc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 3                                                                                COc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 4                                                                              COc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 5                                                                              COc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 6                                                                             COCCOc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 7                                                                           COCCOc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 8                                                                           COCCOc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 9                                                                               Oc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 10                             COc1c(OCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 11                          COc1c(OCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 12                       COc1c(OCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 13                    COc1c(OCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 14              COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 15        COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 16  COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 17                                                                                 COc1c(O)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 18                                                                                COc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 19                                                                             COCCOc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# 20                                                                               COc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 21                                                                             COc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 22                                                                             COc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 23                                                                            COCCOc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# 24                                                                          COCCOc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# 25                                                                          COCCOc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 26                                                                              Oc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# 27                             COc1c(OCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 28                          COc1c(OCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 29                       COc1c(OCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# 30                    COc1c(OCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4ccn5c(CC6CC6)nnc5c4Cl)CC3)cc2)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC
N1CCC(N(Cc2ccc(F)cn2)C(=O)NCc2ccc(OCC(F)(F)F)c(C(F)(F)F)c2)CC1
# 66                                                                    CC(C)COc1ccc(CNC(=O)N(Cc2ccc(F)cc2)C2CCCC(N(C)C)C2)cc1
# 67                                                                      CC(C)COc1ccc(CNC(=O)N(Cc2cccc3sccc23)C2CCN(C)CC2)cc1
# 68                                                                   CC(C)COc1ccc(CNC(=O)N(Cc2cccc3[nH]cnc23)C2CCN(C)CC2)cc1
# 69                                                                         CC(C)COc1ccc(CNC(=O)N(Cc2cn[nH]c2)C2CCN(C)CC2)cc1
# 70                                                                        Cc1noc(C)c1CN(C(=O)NCc1ccc(OCC(C)C)cc1)C1CCN(C)CC1
# 71                                                                        CC(C)COc1ccc(CNC(=O)N(Cc2ccc(F)nc2)C2CCN(C)CC2)cc1
#
#     standard_value bioactivity_label
# 0          11.0000            active
# 1           0.8100            active
# 2           9.3000            active
# 3        1300.0000            medium
# 4        4100.0000            medium
# 5       50000.0000          inactive
# 6        3900.0000            medium
# 7        6000.0000            medium
# 8       50000.0000          inactive
# 9         720.0000            active
# 10       1200.0000            medium
# 11        280.0000            active
# 12        450.0000            active
# 13        270.0000            active
# 14        410.0000            active
# 15        300.0000            active
# 16        520.0000            active
# 17         10.9600            active
# 18          0.8128            active
# 19          9.3330            active
# 20       1288.2500            medium
# 21       4168.6900            medium
# 22      50118.7200          inactive
# 23       3981.0700            medium
# 24       6025.6000            medium
# 25      50118.7200          inactive
# 26        724.4400            active
# 27       1202.2600            medium
# 28        288.4000            active
# 29        446.6800            active
# 30        275.4200            active
# 31        407.3800            active
# 32        302.0000            active
# 33        512.8600            active
# 34         27.3000            active
# 35         75.4000            active
# 36        252.0000            active
# 37        138.8000            active
# 38        110.2000            active
# 39          8.6400            active
# 40         14.7000            active
# 41         43.2000            active
# 42          2.1100            active
# 43          2.1700            active
# 44          0.5400            active
# 45          1.9300            active
# 46          4.6400            active
# 47          4.7000            active
# 48          2.3500            active
# 49          4.2900            active
# 50          3.7800            active
# 51          3.1300            active
# 52         33.4000            active
# 53          2.0500            active
# 54         18.3000            active
# 55         67.2000            active
# 56         26.4000            active
# 57          3.4900            active
# 58          9.9800            active
# 59         20.9000            active
# 60         21.2500            active
# 61         17.2700            active
# 62          6.8600            active
# 63        125.0000            active
# 64         12.0000            active
# 65         27.3000            active
# 66        500.0000            active
# 67        500.0000            active
# 68        500.0000            active
# 69        500.0000            active
# 70        500.0000            active
# 71        500.0000            active

# %% [markdown]
# #### Explore canonical_smiles column and clean the notation
#
# My attempt to apply the concept of list comprehensions for SMILES notation cleaning.This

# %%
def standardize_molecule(data, path):
    
    '''
    This function standardizes molecules by:
    1. Removing unnecessary hydrogens.
    2. Disconnecting metal atoms.
    3. Normalizing the molecule.
    4. Selecting the "parent" molecule.
    5. Neutralizing the molecule.
    Moreover, it removes duplicates based on the 'preprocessed_smiles' column.
    Finally, exports the cleaned table to a specified directory.

    Parameters:
    data (pd.DataFrame): Input DataFrame containing a 'canonical_smiles' column with SMILES strings.
    path (str): Directory path where the preprocessed data will be saved.
    '''
    
    
    # Set up logging
    logging.basicConfig(level=logging.INFO)
    
    # Initialize empty lists to store molecules and their preprocessed SMILES
    mols = []
    preprocessed_smiles = []
    
    #First, convert SMILES strungs to RDKit Mol objects
    for smile in data['canonical_smiles']:
        try:
            mol = Chem.MolFromSmiles(smile)
            if mol is not None:
                mols.append(mol)
            else:
                logging.warning(f"Invalid SMILES string: {smile}")
        except Exception as e:
            logging.error(f"Error processing SMILES string {smile}: {e}")
    
    for mol in mols:
        try:
            #Cleanup: Remove Hs, normalize and disconnect metals
            cleaned_mol = rdMolStandardize.Cleanup(mol)
            #Fragment parent select
            parent_mol = rdMolStandardize.FragmentParent(cleaned_mol)
            
            #Neutralize the molecule
            
            uncharger= rdMolStandardize.Uncharger()
            uncharged_parent_mol = uncharger.uncharge(parent_mol)
            
            #Convert the molecule back to a SMILES string
            smiles=Chem.MolToSmiles(uncharged_parent_mol)
            preprocessed_smiles.append(smiles)
        except Exception as e:
            logging.error(f"Error during molecule standarization:{e}")
            
    # Create a new DataFrame with the preprocessed SMILES
    data = data.copy()
    data['preprocessed_smiles'] = preprocessed_smiles

    # Drop duplicates based on preprocessed smiles
    data.drop_duplicates(subset='preprocessed_smiles', inplace=True)

    # Save the preprocessed data to a CSV file
    data_name = 'preprocessed_data_fingerprint_ready.csv'
    data.to_csv(f"{path}/{data_name}", index=False)

# %%
standardize_molecule(data = df_encoded, path = os.getcwd())
# Out:
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COc1c(O)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1
# [19:28:13] New largest fragment: COc1c(O)cccc1C(=O)C1CCN(CCc2ccc(F)cc2)CC1 (50)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# [19:28:13] New largest fragment: COc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC (53)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COCCOc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC
# [19:28:13] New largest fragment: COCCOc1cccc(C(=O)C2CCN(CCc3ccc(F)cc3)CC2)c1OC (60)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# [19:28:13] New largest fragment: COc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1 (53)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# [19:28:13] New largest fragment: COc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1 (53)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1
# [19:28:13] New largest fragment: COc1ccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)cc1 (53)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COCCOc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1
# [19:28:13] New largest fragment: COCCOc1ccccc1C1CCN(c2ccn3c(CC4CC4)nnc3c2Cl)CC1 (60)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment: COCCOc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1
# [19:28:13] New largest fragment: COCCOc1cccc(C2CCN(c3ccn4c(CC5CC5)nnc4c3Cl)CC2)c1 (60)
# [19:28:13] Running Uncharger
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Initializing MetalDisconnector
# [19:28:13] Running MetalDisconnector
# [19:28:13] Initializing Normalizer
# [19:28:13] Running Normalizer
# [19:28:13] Running LargestFragmentChooser
# [19:28:13] Fragment